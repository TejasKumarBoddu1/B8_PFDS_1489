# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasKumarBoddu1/B8_PFDS_1489/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Quetion 1

# %%
csv_content = """Student_ID,Name,Maths,Science,English,Total
101,Aarav,85,90,,
102,Diya,92,,79,
103,Karan,78,85,92,
104,Meera,,89,84,
105,Rohit,76,80,,
106,Isha,88,,91,
107,Vikram,95,87,,
108,Sneha,81,76,85,
109,Ananya,90,92,,
110,Arjun,,78,88,
111,Neha,77,,82,
112,Sahil,85,85,,
113,Pooja,91,90,86,
114,Dev,,83,80,
115,Riya,74,79,,
116,Kabir,89,95,,
117,Tanya,,87,90,
118,Manav,93,,88,
119,Simran,84,78,,
120,Aditya,80,,77,"""

with open("student_scores_missing.csv", "w", encoding="utf-8") as f:
    f.write(csv_content)

print(" student_scores_missing.csv created!")
# Out:
#  student_scores_missing.csv created!

# %%
import pandas as pd
df = pd.read_csv("student_scores_missing.csv")
df
# Out:
#     Student_ID    Name  Maths  Science  English  Total
# 0          101   Aarav   85.0     90.0      NaN    NaN
# 1          102    Diya   92.0      NaN     79.0    NaN
# 2          103   Karan   78.0     85.0     92.0    NaN
# 3          104   Meera    NaN     89.0     84.0    NaN
# 4          105   Rohit   76.0     80.0      NaN    NaN
# 5          106    Isha   88.0      NaN     91.0    NaN
# 6          107  Vikram   95.0     87.0      NaN    NaN
# 7          108   Sneha   81.0     76.0     85.0    NaN
# 8          109  Ananya   90.0     92.0      NaN    NaN
# 9          110   Arjun    NaN     78.0     88.0    NaN
# 10         111    Neha   77.0      NaN     82.0    NaN
# 11         112   Sahil   85.0     85.0      NaN    NaN
# 12         113   Pooja   91.0     90.0     86.0    NaN
# 13         114     Dev    NaN     83.0     80.0    NaN
# 14         115    Riya   74.0     79.0      NaN    NaN
# 15         116   Kabir   89.0     95.0      NaN    NaN
# ...

# %%
df.loc[df['Student_ID'] == 101, 'English'] = 86
df.loc[df['Student_ID'] == 102, 'Science'] = 84
df.loc[df['Student_ID'] == 104, 'Maths'] = 82
df.loc[df['Student_ID'] == 105, 'English'] = 81
df.loc[df['Student_ID'] == 106, 'Science'] = 89
df.loc[df['Student_ID'] == 107, 'English'] = 90
df.loc[df['Student_ID'] == 109, 'Maths'] = 83
df.loc[df['Student_ID'] == 110, 'Maths'] = 79
df.loc[df['Student_ID'] == 111, 'Science'] = 86
df.loc[df['Student_ID'] == 112, 'English'] = 88
df.loc[df['Student_ID'] == 114, 'Maths'] = 81
df.loc[df['Student_ID'] == 115, 'English'] = 82
df.loc[df['Student_ID'] == 116, 'English'] = 87
df.loc[df['Student_ID'] == 117, 'Maths'] = 85
df.loc[df['Student_ID'] == 118, 'Science'] = 91
df.loc[df['Student_ID'] == 119, 'English'] = 84
df.loc[df['Student_ID'] == 120, 'Science'] = 83
df
# Out:
#     Student_ID    Name  Maths  Science  English  Total
# 0          101   Aarav   85.0     90.0     86.0    NaN
# 1          102    Diya   92.0     84.0     79.0    NaN
# 2          103   Karan   78.0     85.0     92.0    NaN
# 3          104   Meera   82.0     89.0     84.0    NaN
# 4          105   Rohit   76.0     80.0     81.0    NaN
# 5          106    Isha   88.0     89.0     91.0    NaN
# 6          107  Vikram   95.0     87.0     90.0    NaN
# 7          108   Sneha   81.0     76.0     85.0    NaN
# 8          109  Ananya   83.0     92.0      NaN    NaN
# 9          110   Arjun   79.0     78.0     88.0    NaN
# 10         111    Neha   77.0     86.0     82.0    NaN
# 11         112   Sahil   85.0     85.0     88.0    NaN
# 12         113   Pooja   91.0     90.0     86.0    NaN
# 13         114     Dev   81.0     83.0     80.0    NaN
# 14         115    Riya   74.0     79.0     82.0    NaN
# 15         116   Kabir   89.0     95.0     87.0    NaN
# ...

# %%
df['Total'] = df[['Maths','Science','English']].sum(axis=1)
df['Total']
# Out:
# 0     261.0
# 1     255.0
# 2     255.0
# 3     255.0
# 4     237.0
# 5     268.0
# 6     272.0
# 7     242.0
# 8     175.0
# 9     245.0
# 10    245.0
# 11    258.0
# 12    267.0
# 13    244.0
# 14    235.0
# 15    271.0
# 16    262.0
# 17    272.0
# 18    246.0
# 19    240.0
# Name: Total, dtype: float64

# %%
filtered_students = df[
    (df['Maths'] > 80) &
    (df['Science'] > 80) &
    (df['English'] > 80)
]

filtered_students
# Out:
#     Student_ID    Name  Maths  Science  English  Total
# 0          101   Aarav   85.0     90.0     86.0  261.0
# 3          104   Meera   82.0     89.0     84.0  255.0
# 5          106    Isha   88.0     89.0     91.0  268.0
# 6          107  Vikram   95.0     87.0     90.0  272.0
# 11         112   Sahil   85.0     85.0     88.0  258.0
# 12         113   Pooja   91.0     90.0     86.0  267.0
# 15         116   Kabir   89.0     95.0     87.0  271.0
# 16         117   Tanya   85.0     87.0     90.0  262.0
# 17         118   Manav   93.0     91.0     88.0  272.0

# %% [markdown]
# ##Quetion 2

# %%
import pandas as pd
data = {
    "Patient_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Aarav", "Diya", "Karan", "Meera", "Rohit", "Isha", "Vikram", "Sneha", "Ananya", "Lavanya"],
    "Age": [65, 58, None, 72, 45, None, 83, 69, 54, None],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Female", "Female"],
    "Diagnosis": ["Hypertension", "Diabetes", "Asthma", "Diabetes", "Diabetes", "Diabetes", "Heart Disease", "Diabetes", "Arthritis", "Diabetes"],
    "Admission_Date": ["2025-05-10", "2025-06-15", "2025-07-01", "2025-06-20", "2025-05-28","2025-07-10", "2025-06-05", "2025-05-18", "2025-07-12", "2025-06-22"]
}

df = pd.DataFrame(data)

df.to_csv("patients.csv", index=False)

df
# Out:
#    Patient_ID     Name   Age  Gender      Diagnosis Admission_Date
# 0         101    Aarav  65.0    Male   Hypertension     2025-05-10
# 1         102     Diya  58.0  Female       Diabetes     2025-06-15
# 2         103    Karan   NaN    Male         Asthma     2025-07-01
# 3         104    Meera  72.0  Female       Diabetes     2025-06-20
# 4         105    Rohit  45.0    Male       Diabetes     2025-05-28
# 5         106     Isha   NaN  Female       Diabetes     2025-07-10
# 6         107   Vikram  83.0    Male  Heart Disease     2025-06-05
# 7         108    Sneha  69.0  Female       Diabetes     2025-05-18
# 8         109   Ananya  54.0  Female      Arthritis     2025-07-12
# 9         110  Lavanya   NaN  Female       Diabetes     2025-06-22

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
df
# Out:
# /tmp/ipython-input-2796847235.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
#    Patient_ID     Name   Age  Gender      Diagnosis Admission_Date
# 0         101    Aarav  65.0    Male   Hypertension     2025-05-10
# 1         102     Diya  58.0  Female       Diabetes     2025-06-15
# 2         103    Karan  65.0    Male         Asthma     2025-07-01
# 3         104    Meera  72.0  Female       Diabetes     2025-06-20
# ...

# %%
n=df[(df["Gender"]=="Female") & (df["Age"]>50) & (df["Diagnosis"]=="Diabetes")]
n
# Out:
#    Patient_ID     Name   Age  Gender Diagnosis Admission_Date
# 1         102     Diya  58.0  Female  Diabetes     2025-06-15
# 3         104    Meera  72.0  Female  Diabetes     2025-06-20
# 5         106     Isha  65.0  Female  Diabetes     2025-07-10
# 7         108    Sneha  69.0  Female  Diabetes     2025-05-18
# 9         110  Lavanya  65.0  Female  Diabetes     2025-06-22
